# %%
from pathlib import Path
import pandas as pd
import dbnomics

# %%
# [BEA/NIPA-T10106/A191RX-Q]
df = dbnomics.fetch_series('BEA', 'NIPA-T10106', 'A191RX-Q')

# %%
df
# Out:
#     @frequency provider_code dataset_code  \
# 0    quarterly           BEA  NIPA-T10106
# 1    quarterly           BEA  NIPA-T10106
# 2    quarterly           BEA  NIPA-T10106
# 3    quarterly           BEA  NIPA-T10106
# 4    quarterly           BEA  NIPA-T10106
# ..         ...           ...          ...
# 293  quarterly           BEA  NIPA-T10106
# 294  quarterly           BEA  NIPA-T10106
# 295  quarterly           BEA  NIPA-T10106
# 296  quarterly           BEA  NIPA-T10106
# 297  quarterly           BEA  NIPA-T10106
#
#                                           dataset_name series_code  \
# 0    Table 1.1.6. Real Gross Domestic Product, Chai...    A191RX-Q
# 1    Table 1.1.6. Real Gross Domestic Product, Chai...    A191RX-Q
# 2    Table 1.1.6. Real Gross Domestic Product, Chai...    A191RX-Q
# 3    Table 1.1.6. Real Gross Domestic Product, Chai...    A191RX-Q
# 4    Table 1.1.6. Real Gross Domestic Product, Chai...    A191RX-Q
# ...

# %%
path = Path.cwd().joinpath('DataDbnomicsAPI')
csvFile = 'dbnomicsApiInfo.csv'
csvDf = pd.read_csv(path/csvFile)
parquetFile = 'dbnomicsApiInfo.parquet'
csvDf.to_parquet(path/parquetFile)

# %%
parquetDf = pd.read_parquet(path/parquetFile)
parquetDf
# Out:
#            country                                           indcator  \
# 0    Untied states       Real Gross Domestic Product, Chained Dollars
# 1            Japan  GDP (expenditure approach) and its components ...
# 2         Germany             Gross domestic product at market prices
# 3   Untied kingdom            Gross Domestic Product : chained volume
# 4           France            Gross domestic product at market prices
# 5    Untied states                                  Unemployment Rate
# 6   Untied kingdom  Unemployment rate (aged 16 and over, seasonall...
# 7         Germany   Unemployment by sex and age – monthly data(Sea...
# 8           France  Unemployment by sex and age – monthly data(Sea...
# 9    Untied states  Employment rate > Aged 15-64 > All persons – L...
# 10           Japan  Employment rate > Aged 15-64 > All persons – L...
# 11        Germany   Employment rate > Aged 15-64 > All persons – L...
# ...
